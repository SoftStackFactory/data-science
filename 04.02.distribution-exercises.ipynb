# %% [markdown]
# <hr>
#
# ##### Mount Drive - **Google Colab Only Step**
#
# When using google colab in order to access files on our google drive we need to mount the drive by running the below python cell, then clicking the link it generates and pasting the code in the cell.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Change Directory To Access The Dependent Files - **Google Colab Only Step**

# %%
directory = "student"
if (directory == "student"):
  # %cd drive/My\ Drive/Colab\ Notebooks/data-science-track/
else:
  # %cd drive/Shared\ drives/Rubrik/Data\ Science/Course/Data-Science-Track

# %% [markdown]
# # Distributions Recap
#
# In general we can think of distributions as a way of counting occurances of unique values generated by a random generator.
#
# More technically the distribution of a statistical data set (or a population) is a listing or function showing all the possible values (or intervals) of the data and how often they occur.
#
# The frequency of occurrence or the natural geographic range or place where any item or category of items occurs.
#
#
# <hr>

# %% [markdown]
# ## Bernoulli Distribution Recap
#
# A Bernoulli distribution has only two possible outcomes, namely 1 (success) and 0 (failure), and a single trial.
#
# So the random variable X which has a Bernoulli distribution can take value 1 with the probability of success, say p, and the value 0 with the probability of failure, say q or 1-p.

# %% [markdown]
# ### Bernouli Distribution Exercise
#
# Generate 1000 samples of coin flips using the bernoulli distribution. Where flipping heads has a 50% chance.
#
# #### Step 1: Import libraries
# - scipy.stats
# - bernoulli seaborn

# %% [markdown]
# ##### Step 2:  Generate random numbers from N(0,1) using a bernoulli generator

# %% [markdown]
# ##### Step 3: Plot Distribution
# - Use the distplot function from the seaborn library to visualize the simulations

# %% [markdown]
# ### Data Analysis Questions:
# 1. Why are there only two unique frequency values?
# 2. When should I not use a bernoulli plot?

# %% [markdown]
# <hr>
#
# ## Normal Distributions (Bell Curve) Recap
#
# A normal distribution is a distribution that resembles a bell (hence the nickname). The bell curve is symmetrical. Half of the data will fall to the left of the mean, half will fall to the right.

# %% [markdown]
# ### Normal Distribution Exercise
#
# Randomly generate 20 samples using the normal distribution and compare the results to generating 1000 samples.
#
# #### Step 1: Import libraries:
#  - normal distribution from scipy stats
#  - seaborn

# %% [markdown]
# #### Step 2: Generate random numbers from N(0,1) using a normal distribution generator

# %% [markdown]
# #### Step 3: Plot the distribution
# - Use the distplot function from the seaborn library to visualize the simulations

# %% [markdown]
# ### Data Analysis Questions:
# 1. What are some properties of a normal distribution?
# 2. What is the total area of this graph?
# 3. Why are there exactly half of the values are to the left of mean and exactly half the values are to the right?

# %% [markdown]
# <hr>
#
# ## Negative Binomial
#
# A negative binomial distribution (also called the Pascal Distribution) is a discrete probability distribution for random variables in a negative binomial experiment.
#
# More technically this is a discrete probability distribution of the number of successes in a sequence of independent and identically distributed Bernoulli trials before a specified (non-random) number of failures (denoted r) occurs.
#
#
# ### Negative Binomial Exercise
# Generate random numbers using the negative binomial distribution
#
# Where:
# - n = 10 trials
# - size= 1000 of simulations

# %% [markdown]
# #### Step 1: Import the negative binomial distribution from scipy

# %% [markdown]
# ##### Step 2: Run the similation
# Where:
# - n is the first argument
# - chance is the second argument
# - size is the third argument

# %% [markdown]
# #### Step 3: Plot the distribution
# - Use the distplot function from the seaborn library to visualize the simulations

# %% [markdown]
# ### Data Analysis Questions:
#
# - When and why would you use this distribution?

# %% [markdown]
# <hr>
#
# ## Continuous Distributions
#
# **Note:** that for continuous distributions the probability at a single point is essentially 0 because there are an infinite amount of values a point could be.
#
#
# ### Probability Density Function Recap
#
# Probability density function (PDF) is a statistical expression that defines a probability distribution for a continuous random variable as opposed to a discrete random variable.

# %% [markdown]
# #### Probability Density Function Exercise
#
# Generate 500 random samples using numpy normal distribution and then visualize it with a histogram

# %% [markdown]
# #### Step 1 Import libraries
#  scipy stats
#  numpy
#  pylot

# %% [markdown]
# #### Step 2: Generate random numbers from N(0,1) using a normal distribution generator

# %% [markdown]
# #### Step 3: Create numpy histogram

# %% [markdown]
# ##### Step 4: Create a PDF

# %% [markdown]
# ##### Step 5: Plot the histogram

# %% [markdown]
# ##### Step 6: Plot the histogram

# %% [markdown]
# ### Data Analysis Questions:
#
# - When and why would you use this distribution?

# %% [markdown]
# <hr>
#
# ### Cumalitive Density Function Recap
# The cumulative distribution function (cdf) is the probability that the variable takes a value less than or equal to x.

# %% [markdown]
# #### Probability Cumulative Density Function Exercise
#
# Generate 500 random samples using numpy normal distribution and then visualize it with a histogram

# %% [markdown]
# #### Step 1: Import libraries
# - scipy stats
# -  numpy
# - pylot

# %% [markdown]
# #### Step 2: Generate random numbers from N(0,1) using a normal distribution generator

# %% [markdown]
# #### Step 3: Create numpy histogram

# %% [markdown]
# ##### Step 4: Create a PDF

# %% [markdown]
# ##### Step 5: Plot the histogram

# %% [markdown]
# ##### Step 6: Plot the histogram

# %% [markdown]
# ### Data Analysis Questions:
#
# - When and why would you use this distribution?
