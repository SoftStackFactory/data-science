# %% [markdown]
# <hr>
#
# ##### Mount Drive - **Google Colab Only Step**
#
# When using google colab in order to access files on our google drive we need to mount the drive by running the below python cell, then clicking the link it generates and pasting the code in the cell.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Change Directory To Access The Dependent Files - **Google Colab Only Step**

# %%
directory = "student"
if (directory == "student"):
  # %cd drive/Colab\ Notebooks/data-science-track/
else:
  # %cd drive/Shared\ drives/Rubrik/Data\ Science/Course/Data-Science-Track

# %% [markdown]
# <hr>

# %% [markdown]
# ### Import Libraries

# %% [markdown]
# #### Import numpy

# %% [markdown]
# #### Import pandas

# %% [markdown]
# #### Import matplotlib

# %% [markdown]
# #### Import seaborn

# %% [markdown]
# #### Set the library configurations
# Specifically use seaborn graphs rather than matplotlib's graphs
#
# ```python
# sns.set() # make seaborn override the styling of matplotlib graphs
# ```

# %% [markdown]
# ### Import Data
# Read in the iris dataset using the following path and store it in a variable called `iris`
# ```python
# path = './data/iris.csv'
# ```

# %% [markdown]
# <hr>
#
# <br>
#
# ### Understand the data
# #### Print the head of the Iris dataset

# %% [markdown]
# <hr>
#
# <br>
#
# ### Filter your DataFrame
# Pick a species to filter your DataFrame by.
#
# #### Create a boolean series to target the desired rows of a particular species

# %% [markdown]
# #### Using the boolean series index the iris data set and store the resulting data frame in a new variable

# %% [markdown]
# #### Print the shape of the new DataFrame

# %% [markdown]
# #### Run a .dtypes to look at the columns that are available to compare

# %% [markdown]
# <hr>
#
# <br>
#
# ### Violin Plot
# #### Show a violin plot of the virginica `SepalLengthCm`

# %% [markdown]
# #### Show a violin plot of the virginica `SepalLengthCm`

# %% [markdown]
# <hr>
#
# <br>
#
# ### Scatter Plots
#
# Using a scatter plot let us plot the "SepalLengthCm" and the "SepalWidthCm" features to see how the fluctuate together.

# %% [markdown]
# #### Create variables to hold the features you want to compare

# %% [markdown]
# #### Create and show the scatter plot using the variables you just created

# %% [markdown]
# ### What can we say about this plot?
# ####  Is this relationship a correlation or a causation?

# %% [markdown]
# ####  If it is a correlation what type of correlation is it?

# %% [markdown]
# <hr>
#
# <br>
#
# ### Covariance
#
# Using the numpy funtion np.cov() create a covariance matrix and print the covariance.
#
# #### Index Keys for a 2 by 2 matrix:
# - [0,0] : Variance for feature 1
# - [0,1] : Covariance for both features
# - [1,0] : Covariance for both features
# - [1,1] : Variance for feature 2

# %% [markdown]
# <hr>
#
# <br>
#
# ### Pearson Correlation Coefficient

# %%
def pearson_coeff(feat_1, feat_2, df):
    """
        Info:
            This function will return the pearson coefficent, a value between 
            -1 and 1 to signify the type of correlation.   
        Params:
            feat_1 (type: string), column name
            feat_2 (type: string), column name 
            df (type: Pandas DataFrame)
        Output:
            pearson coefficent value (type: float)
    """
    x = df[feat_1]
    y = df[feat_2]
    
    covar = np.cov(x,y)[0,1]
    std_x = np.std(x)
    std_y = np.std(y)
    
    
    print('Pearson Correlation Coefficient:')
    print(feat_1, "VS.", feat_2)
    
    return covar / (std_x * std_y)

# %% [markdown]
# #### Call / Invoke the pearson_coeff function with the 2 features that were defined above.
# Passing in the following arguments with variables we assigned earlier:
# - feat_1 = `feat1`
# - feat_2 = `feat2`
# - df = `DataFrame` you created

# %% [markdown]
# ### What is the pearson correlation coefficient saying
# #### Why do we use the pearson correlation coefficent over the covariance formula?

# %% [markdown]
# #### Is it a positive correlation, negative correlation, or is there no correlation

# %% [markdown]
# #### After identifying what type it is, explain why you think this might be

# %% [markdown]
# <hr>
#
# <br>
#
# ### Repeat the previous to find an example for the 3 differtent types of correlations that the Pearson Correlation Coefficient describes!
#
# #### The different types are listed below... Go ahead and count your first set of numerical columns to whichever category of the 3 it ends up falling under.

# %% [markdown]
# ### 1. Negative Correlation

# %% [markdown]
# #### Create variables to hold the features you want to compare

# %% [markdown]
# #### Create scatter plot using the variables you just created

# %% [markdown]
# #### Show the plot you just created

# %% [markdown]
# #### Using the numpy funtion np.cov() create a covariance matrix and print the covariance.
#
# #### Index Keys for a 2 by 2 matrix:
# - [0,0] : Variance for feature 1
# - [0,1] : Covariance for both features
# - [1,0] : Covariance for both features
# - [1,1] : Variance for feature 2

# %% [markdown]
# #### Call / Invoke the pearson_coeff function with the 2 features that were defined above.
# Passing in the following arguments with variables we assigned earlier:
# - feat_1 = `feat1`
# - feat_2 = `feat2`
# - df = `DataFrame` you created

# %% [markdown]
# ### What can we say about this plot?
# ####  Is this relationship a correlation or a causation? Elaborate.

# %% [markdown]
# #### Why do we tend to use the pearson correlation coefficent over the covariance formula?

# %% [markdown]
# #### Is the pearson correlation coefficent what you expected it to be? Elaborate why or why not.

# %% [markdown]
# #### 2. No Correlation

# %% [markdown]
# #### Create variables to hold the features you want to compare

# %% [markdown]
# #### Create scatter plot using the variables you just created

# %% [markdown]
# #### Show the plot you just created

# %% [markdown]
# #### Using the numpy funtion np.cov() create a covariance matrix and print the covariance.
#
# #### Index Keys for a 2 by 2 matrix:
# - [0,0] : Variance for feature 1
# - [0,1] : Covariance for both features
# - [1,0] : Covariance for both features
# - [1,1] : Variance for feature 2

# %% [markdown]
# #### Call / Invoke the pearson_coeff function with the 2 features that were defined above.
# Passing in the following arguments with variables we assigned earlier:
# - feat_1 = `feat1`
# - feat_2 = `feat2`
# - df = `DataFrame` you created

# %% [markdown]
# ### What can we say about this plot?
# ####  Is this relationship a correlation or a causation? Elaborate.

# %% [markdown]
# #### Why do we tend to use the pearson correlation coefficent over the covariance formula?

# %% [markdown]
# #### Is the pearson correlation coefficent what you expected it to be? Elaborate why or why not.

# %% [markdown]
# #### 3. Positive Correlation

# %% [markdown]
# #### Create variables to hold the features you want to compare

# %% [markdown]
# #### Create scatter plot using the variables you just created

# %% [markdown]
# #### Show the plot you just created

# %% [markdown]
# #### Using the numpy funtion np.cov() create a covariance matrix and print the covariance.
#
# #### Index Keys for a 2 by 2 matrix:
# - [0,0] : Variance for feature 1
# - [0,1] : Covariance for both features
# - [1,0] : Covariance for both features
# - [1,1] : Variance for feature 2

# %% [markdown]
# #### Call / Invoke the pearson_coeff function with the 2 features that were defined above.
# Passing in the following arguments with variables we assigned earlier:
# - feat_1 = `feat1`
# - feat_2 = `feat2`
# - df = `DataFrame` you created

# %% [markdown]
# ### What can we say about this plot?
# ####  Is this relationship a correlation or a causation? Elaborate.

# %% [markdown]
# #### Why do we tend to use the pearson correlation coefficent over the covariance formula?

# %% [markdown]
# #### Is the pearson correlation coefficent what you expected it to be? Elaborate why or why not.
